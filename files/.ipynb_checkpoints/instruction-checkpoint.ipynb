# %%
# Step 1: Install
pip install -r requirements.txt

# Step 2: Sanity check (~1 min, verifies all models work)
python sanity_check.py

# Step 3: Quick smoke test (5 epochs, ~10 min)
python run_experiments.py --epochs 5

# Step 4: Full run (100 epochs, ~8-12h on GPU)
python run_experiments.py

# Step 5: Generate plots after training
python plot_results.py

# %% [markdown]
# https://docs.google.com/document/d/1b52l_oIuq9PWL0E-7dHuWj0tKyUe0t02pUU3lQ0Ut2M/edit?usp=sharing
